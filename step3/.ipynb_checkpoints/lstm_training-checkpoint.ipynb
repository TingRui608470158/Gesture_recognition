# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %%
dataset = 'output_all.csv'
model_save_path = 'lstm_model/point_history_center.hdf5'

# %%
NUM_CLASSES = 7
TIME_STEPS = 16
DIMENSION = 2

# %% [markdown]
# # Dataset reading

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1)))
print(X_dataset.shape)
# Out:
# (1088, 32)

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))
print(y_dataset.shape)
# Out:
# (1088,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (816, 32)
# (816,)
# (272, 32)
# (272,)

# %% [markdown]
# # Model building

# %%
use_lstm = True
model = None

if use_lstm:
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
        tf.keras.layers.Reshape((TIME_STEPS, DIMENSION), input_shape=(TIME_STEPS * DIMENSION, )), 
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.LSTM(32, input_shape=[TIME_STEPS, DIMENSION]),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
else:
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(24, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 16, 2)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 2)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                4480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                330
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 77
# =================================================================
# Total params: 4,887
# Trainable params: 4,887
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    y_train,
    epochs=2000,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/2000
# 26/26 [==============================] - 7s 12ms/step - loss: 1.9386 - accuracy: 0.3309 - val_loss: 1.9381 - val_accuracy: 0.4301
#
# Epoch 00001: saving model to lstm_model/point_history_center.hdf5
# Epoch 2/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.9302 - accuracy: 0.4498 - val_loss: 1.9305 - val_accuracy: 0.4449
#
# Epoch 00002: saving model to lstm_model/point_history_center.hdf5
# Epoch 3/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.9229 - accuracy: 0.4596 - val_loss: 1.9228 - val_accuracy: 0.4522
#
# Epoch 00003: saving model to lstm_model/point_history_center.hdf5
# Epoch 4/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.9135 - accuracy: 0.4681 - val_loss: 1.9150 - val_accuracy: 0.4559
#
# Epoch 00004: saving model to lstm_model/point_history_center.hdf5
# Epoch 5/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.9047 - accuracy: 0.4608 - val_loss: 1.9061 - val_accuracy: 0.4559
#
# Epoch 00005: saving model to lstm_model/point_history_center.hdf5
# Epoch 6/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.8944 - accuracy: 0.4645 - val_loss: 1.8966 - val_accuracy: 0.4559
#
# Epoch 00006: saving model to lstm_model/point_history_center.hdf5
# Epoch 7/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.8828 - accuracy: 0.4694 - val_loss: 1.8860 - val_accuracy: 0.4559
#
# Epoch 00007: saving model to lstm_model/point_history_center.hdf5
# Epoch 8/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.8699 - accuracy: 0.4608 - val_loss: 1.8737 - val_accuracy: 0.4522
#
# Epoch 00008: saving model to lstm_model/point_history_center.hdf5
# Epoch 9/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.8556 - accuracy: 0.4571 - val_loss: 1.8597 - val_accuracy: 0.4522
#
# Epoch 00009: saving model to lstm_model/point_history_center.hdf5
# Epoch 10/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.8394 - accuracy: 0.4608 - val_loss: 1.8432 - val_accuracy: 0.4522
#
# Epoch 00010: saving model to lstm_model/point_history_center.hdf5
# Epoch 11/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.8184 - accuracy: 0.4547 - val_loss: 1.8235 - val_accuracy: 0.4522
#
# Epoch 00011: saving model to lstm_model/point_history_center.hdf5
# Epoch 12/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.7956 - accuracy: 0.4645 - val_loss: 1.7978 - val_accuracy: 0.4522
#
# Epoch 00012: saving model to lstm_model/point_history_center.hdf5
# Epoch 13/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.7673 - accuracy: 0.4583 - val_loss: 1.7683 - val_accuracy: 0.4559
#
# Epoch 00013: saving model to lstm_model/point_history_center.hdf5
# Epoch 14/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.7283 - accuracy: 0.4571 - val_loss: 1.7349 - val_accuracy: 0.4522
#
# Epoch 00014: saving model to lstm_model/point_history_center.hdf5
# Epoch 15/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.6973 - accuracy: 0.4596 - val_loss: 1.7015 - val_accuracy: 0.4485
#
# Epoch 00015: saving model to lstm_model/point_history_center.hdf5
# Epoch 16/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.6578 - accuracy: 0.4596 - val_loss: 1.6723 - val_accuracy: 0.4559
#
# Epoch 00016: saving model to lstm_model/point_history_center.hdf5
# Epoch 17/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.6262 - accuracy: 0.4694 - val_loss: 1.6468 - val_accuracy: 0.4596
#
# Epoch 00017: saving model to lstm_model/point_history_center.hdf5
# Epoch 18/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.5997 - accuracy: 0.4669 - val_loss: 1.6231 - val_accuracy: 0.4596
#
# Epoch 00018: saving model to lstm_model/point_history_center.hdf5
# Epoch 19/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.5849 - accuracy: 0.4730 - val_loss: 1.6015 - val_accuracy: 0.4559
#
# Epoch 00019: saving model to lstm_model/point_history_center.hdf5
# Epoch 20/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.5615 - accuracy: 0.4816 - val_loss: 1.5855 - val_accuracy: 0.4632
#
# Epoch 00020: saving model to lstm_model/point_history_center.hdf5
# Epoch 21/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.5417 - accuracy: 0.4792 - val_loss: 1.5713 - val_accuracy: 0.4596
#
# Epoch 00021: saving model to lstm_model/point_history_center.hdf5
# Epoch 22/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.5372 - accuracy: 0.4792 - val_loss: 1.5552 - val_accuracy: 0.4706
#
# Epoch 00022: saving model to lstm_model/point_history_center.hdf5
# Epoch 23/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.5180 - accuracy: 0.4877 - val_loss: 1.5398 - val_accuracy: 0.4706
#
# Epoch 00023: saving model to lstm_model/point_history_center.hdf5
# Epoch 24/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.5044 - accuracy: 0.4939 - val_loss: 1.5256 - val_accuracy: 0.4706
#
# Epoch 00024: saving model to lstm_model/point_history_center.hdf5
# Epoch 25/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4886 - accuracy: 0.4963 - val_loss: 1.5089 - val_accuracy: 0.4743
#
# Epoch 00025: saving model to lstm_model/point_history_center.hdf5
# Epoch 26/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4729 - accuracy: 0.4988 - val_loss: 1.4933 - val_accuracy: 0.4816
#
# Epoch 00026: saving model to lstm_model/point_history_center.hdf5
# Epoch 27/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4508 - accuracy: 0.5074 - val_loss: 1.4755 - val_accuracy: 0.4853
#
# Epoch 00027: saving model to lstm_model/point_history_center.hdf5
# Epoch 28/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4366 - accuracy: 0.5074 - val_loss: 1.4570 - val_accuracy: 0.4890
#
# Epoch 00028: saving model to lstm_model/point_history_center.hdf5
# Epoch 29/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4300 - accuracy: 0.5233 - val_loss: 1.4417 - val_accuracy: 0.5074
#
# Epoch 00029: saving model to lstm_model/point_history_center.hdf5
# Epoch 30/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.4115 - accuracy: 0.5392 - val_loss: 1.4257 - val_accuracy: 0.5184
#
# Epoch 00030: saving model to lstm_model/point_history_center.hdf5
# Epoch 31/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.3823 - accuracy: 0.5368 - val_loss: 1.4017 - val_accuracy: 0.5184
#
# Epoch 00031: saving model to lstm_model/point_history_center.hdf5
# Epoch 32/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.3718 - accuracy: 0.5527 - val_loss: 1.3843 - val_accuracy: 0.5331
#
# Epoch 00032: saving model to lstm_model/point_history_center.hdf5
# Epoch 33/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.3455 - accuracy: 0.5625 - val_loss: 1.3619 - val_accuracy: 0.5515
#
# Epoch 00033: saving model to lstm_model/point_history_center.hdf5
# Epoch 34/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.3292 - accuracy: 0.5527 - val_loss: 1.3459 - val_accuracy: 0.5551
#
# Epoch 00034: saving model to lstm_model/point_history_center.hdf5
# Epoch 35/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.3064 - accuracy: 0.5637 - val_loss: 1.3238 - val_accuracy: 0.5588
#
# Epoch 00035: saving model to lstm_model/point_history_center.hdf5
# Epoch 36/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.2948 - accuracy: 0.5735 - val_loss: 1.3119 - val_accuracy: 0.5588
#
# Epoch 00036: saving model to lstm_model/point_history_center.hdf5
# Epoch 37/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.2787 - accuracy: 0.5662 - val_loss: 1.2911 - val_accuracy: 0.5588
#
# Epoch 00037: saving model to lstm_model/point_history_center.hdf5
# Epoch 38/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.2550 - accuracy: 0.5686 - val_loss: 1.2707 - val_accuracy: 0.5588
#
# Epoch 00038: saving model to lstm_model/point_history_center.hdf5
# Epoch 39/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.2457 - accuracy: 0.5735 - val_loss: 1.2614 - val_accuracy: 0.5515
#
# Epoch 00039: saving model to lstm_model/point_history_center.hdf5
# Epoch 40/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.2246 - accuracy: 0.5686 - val_loss: 1.2428 - val_accuracy: 0.5588
#
# Epoch 00040: saving model to lstm_model/point_history_center.hdf5
# Epoch 41/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1956 - accuracy: 0.5821 - val_loss: 1.2371 - val_accuracy: 0.5588
#
# Epoch 00041: saving model to lstm_model/point_history_center.hdf5
# Epoch 42/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1793 - accuracy: 0.5723 - val_loss: 1.2330 - val_accuracy: 0.5662
#
# Epoch 00042: saving model to lstm_model/point_history_center.hdf5
# Epoch 43/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1852 - accuracy: 0.5784 - val_loss: 1.2107 - val_accuracy: 0.5588
#
# Epoch 00043: saving model to lstm_model/point_history_center.hdf5
# Epoch 44/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1661 - accuracy: 0.5833 - val_loss: 1.1879 - val_accuracy: 0.5551
#
# Epoch 00044: saving model to lstm_model/point_history_center.hdf5
# Epoch 45/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1501 - accuracy: 0.5809 - val_loss: 1.1813 - val_accuracy: 0.5515
#
# Epoch 00045: saving model to lstm_model/point_history_center.hdf5
# Epoch 46/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1567 - accuracy: 0.5748 - val_loss: 1.1658 - val_accuracy: 0.5551
#
# Epoch 00046: saving model to lstm_model/point_history_center.hdf5
# Epoch 47/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1406 - accuracy: 0.5797 - val_loss: 1.1546 - val_accuracy: 0.5551
#
# Epoch 00047: saving model to lstm_model/point_history_center.hdf5
# Epoch 48/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1331 - accuracy: 0.5858 - val_loss: 1.1551 - val_accuracy: 0.5551
#
# Epoch 00048: saving model to lstm_model/point_history_center.hdf5
# Epoch 49/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1268 - accuracy: 0.5919 - val_loss: 1.1350 - val_accuracy: 0.5588
#
# Epoch 00049: saving model to lstm_model/point_history_center.hdf5
# Epoch 50/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1220 - accuracy: 0.5882 - val_loss: 1.1318 - val_accuracy: 0.5662
#
# Epoch 00050: saving model to lstm_model/point_history_center.hdf5
# Epoch 51/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0978 - accuracy: 0.5846 - val_loss: 1.1234 - val_accuracy: 0.5699
#
# Epoch 00051: saving model to lstm_model/point_history_center.hdf5
# Epoch 52/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0950 - accuracy: 0.5919 - val_loss: 1.1173 - val_accuracy: 0.5772
#
# Epoch 00052: saving model to lstm_model/point_history_center.hdf5
# Epoch 53/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1024 - accuracy: 0.5931 - val_loss: 1.1262 - val_accuracy: 0.5809
#
# Epoch 00053: saving model to lstm_model/point_history_center.hdf5
# Epoch 54/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0833 - accuracy: 0.6005 - val_loss: 1.1060 - val_accuracy: 0.5772
#
# Epoch 00054: saving model to lstm_model/point_history_center.hdf5
# Epoch 55/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0897 - accuracy: 0.5956 - val_loss: 1.1343 - val_accuracy: 0.5846
#
# Epoch 00055: saving model to lstm_model/point_history_center.hdf5
# Epoch 56/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0790 - accuracy: 0.6091 - val_loss: 1.1354 - val_accuracy: 0.5846
#
# Epoch 00056: saving model to lstm_model/point_history_center.hdf5
# Epoch 57/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0829 - accuracy: 0.6078 - val_loss: 1.0905 - val_accuracy: 0.5956
#
# Epoch 00057: saving model to lstm_model/point_history_center.hdf5
# Epoch 58/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0776 - accuracy: 0.6152 - val_loss: 1.1125 - val_accuracy: 0.5956
#
# Epoch 00058: saving model to lstm_model/point_history_center.hdf5
# Epoch 59/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0782 - accuracy: 0.6103 - val_loss: 1.1173 - val_accuracy: 0.5993
#
# Epoch 00059: saving model to lstm_model/point_history_center.hdf5
# Epoch 60/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0890 - accuracy: 0.6140 - val_loss: 1.0831 - val_accuracy: 0.5735
#
# Epoch 00060: saving model to lstm_model/point_history_center.hdf5
# Epoch 61/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0705 - accuracy: 0.6250 - val_loss: 1.0858 - val_accuracy: 0.5735
#
# Epoch 00061: saving model to lstm_model/point_history_center.hdf5
# Epoch 62/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0680 - accuracy: 0.6213 - val_loss: 1.0824 - val_accuracy: 0.5735
#
# Epoch 00062: saving model to lstm_model/point_history_center.hdf5
# Epoch 63/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0552 - accuracy: 0.6115 - val_loss: 1.0913 - val_accuracy: 0.5662
#
# Epoch 00063: saving model to lstm_model/point_history_center.hdf5
# Epoch 64/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0488 - accuracy: 0.6127 - val_loss: 1.0936 - val_accuracy: 0.5699
#
# Epoch 00064: saving model to lstm_model/point_history_center.hdf5
# Epoch 65/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0470 - accuracy: 0.6176 - val_loss: 1.0776 - val_accuracy: 0.5625
#
# Epoch 00065: saving model to lstm_model/point_history_center.hdf5
# Epoch 66/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0632 - accuracy: 0.6078 - val_loss: 1.0710 - val_accuracy: 0.5662
#
# Epoch 00066: saving model to lstm_model/point_history_center.hdf5
# Epoch 67/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0502 - accuracy: 0.6140 - val_loss: 1.0671 - val_accuracy: 0.5625
#
# Epoch 00067: saving model to lstm_model/point_history_center.hdf5
# Epoch 68/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0421 - accuracy: 0.6127 - val_loss: 1.0770 - val_accuracy: 0.5699
#
# Epoch 00068: saving model to lstm_model/point_history_center.hdf5
# Epoch 69/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0297 - accuracy: 0.6127 - val_loss: 1.0806 - val_accuracy: 0.5699
#
# Epoch 00069: saving model to lstm_model/point_history_center.hdf5
# Epoch 70/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0276 - accuracy: 0.6140 - val_loss: 1.0608 - val_accuracy: 0.5699
#
# Epoch 00070: saving model to lstm_model/point_history_center.hdf5
# Epoch 71/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0335 - accuracy: 0.6140 - val_loss: 1.0642 - val_accuracy: 0.5662
#
# Epoch 00071: saving model to lstm_model/point_history_center.hdf5
# Epoch 72/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0257 - accuracy: 0.6152 - val_loss: 1.0738 - val_accuracy: 0.5735
#
# Epoch 00072: saving model to lstm_model/point_history_center.hdf5
# Epoch 73/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0188 - accuracy: 0.6115 - val_loss: 1.0602 - val_accuracy: 0.5662
#
# Epoch 00073: saving model to lstm_model/point_history_center.hdf5
# Epoch 74/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0205 - accuracy: 0.6201 - val_loss: 1.0533 - val_accuracy: 0.5699
#
# Epoch 00074: saving model to lstm_model/point_history_center.hdf5
# Epoch 75/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0335 - accuracy: 0.6017 - val_loss: 1.0926 - val_accuracy: 0.5772
#
# Epoch 00075: saving model to lstm_model/point_history_center.hdf5
# Epoch 76/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0168 - accuracy: 0.6054 - val_loss: 1.0715 - val_accuracy: 0.5662
#
# Epoch 00076: saving model to lstm_model/point_history_center.hdf5
# Epoch 77/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0063 - accuracy: 0.6152 - val_loss: 1.0521 - val_accuracy: 0.5625
#
# Epoch 00077: saving model to lstm_model/point_history_center.hdf5
# Epoch 78/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0111 - accuracy: 0.6152 - val_loss: 1.0401 - val_accuracy: 0.5625
#
# Epoch 00078: saving model to lstm_model/point_history_center.hdf5
# Epoch 79/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9954 - accuracy: 0.6140 - val_loss: 1.0381 - val_accuracy: 0.5625
#
# Epoch 00079: saving model to lstm_model/point_history_center.hdf5
# Epoch 80/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0017 - accuracy: 0.6127 - val_loss: 1.0357 - val_accuracy: 0.5625
#
# Epoch 00080: saving model to lstm_model/point_history_center.hdf5
# Epoch 81/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9970 - accuracy: 0.6201 - val_loss: 1.0513 - val_accuracy: 0.5662
#
# Epoch 00081: saving model to lstm_model/point_history_center.hdf5
# Epoch 82/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0044 - accuracy: 0.6164 - val_loss: 1.0576 - val_accuracy: 0.5735
#
# Epoch 00082: saving model to lstm_model/point_history_center.hdf5
# Epoch 83/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0071 - accuracy: 0.6176 - val_loss: 1.0455 - val_accuracy: 0.5735
#
# Epoch 00083: saving model to lstm_model/point_history_center.hdf5
# Epoch 84/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9996 - accuracy: 0.6115 - val_loss: 1.0230 - val_accuracy: 0.5625
#
# Epoch 00084: saving model to lstm_model/point_history_center.hdf5
# Epoch 85/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9990 - accuracy: 0.6091 - val_loss: 1.0169 - val_accuracy: 0.5625
#
# Epoch 00085: saving model to lstm_model/point_history_center.hdf5
# Epoch 86/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9977 - accuracy: 0.6152 - val_loss: 1.0225 - val_accuracy: 0.5772
#
# Epoch 00086: saving model to lstm_model/point_history_center.hdf5
# Epoch 87/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9792 - accuracy: 0.6152 - val_loss: 1.0313 - val_accuracy: 0.5735
#
# Epoch 00087: saving model to lstm_model/point_history_center.hdf5
# Epoch 88/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9851 - accuracy: 0.6189 - val_loss: 1.0248 - val_accuracy: 0.5772
#
# Epoch 00088: saving model to lstm_model/point_history_center.hdf5
# Epoch 89/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9721 - accuracy: 0.6336 - val_loss: 1.0315 - val_accuracy: 0.5699
#
# Epoch 00089: saving model to lstm_model/point_history_center.hdf5
# Epoch 90/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9886 - accuracy: 0.6189 - val_loss: 1.0088 - val_accuracy: 0.5772
#
# Epoch 00090: saving model to lstm_model/point_history_center.hdf5
# Epoch 91/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9791 - accuracy: 0.6250 - val_loss: 1.0158 - val_accuracy: 0.5772
#
# Epoch 00091: saving model to lstm_model/point_history_center.hdf5
# Epoch 92/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9774 - accuracy: 0.6152 - val_loss: 1.0051 - val_accuracy: 0.5846
#
# Epoch 00092: saving model to lstm_model/point_history_center.hdf5
# Epoch 93/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9534 - accuracy: 0.6238 - val_loss: 1.0062 - val_accuracy: 0.5809
#
# Epoch 00093: saving model to lstm_model/point_history_center.hdf5
# Epoch 94/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9698 - accuracy: 0.6201 - val_loss: 1.0003 - val_accuracy: 0.5809
#
# Epoch 00094: saving model to lstm_model/point_history_center.hdf5
# Epoch 95/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9518 - accuracy: 0.6238 - val_loss: 0.9950 - val_accuracy: 0.5846
#
# Epoch 00095: saving model to lstm_model/point_history_center.hdf5
# Epoch 96/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9550 - accuracy: 0.6201 - val_loss: 0.9968 - val_accuracy: 0.5919
#
# Epoch 00096: saving model to lstm_model/point_history_center.hdf5
# Epoch 97/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9471 - accuracy: 0.6348 - val_loss: 0.9912 - val_accuracy: 0.5882
#
# Epoch 00097: saving model to lstm_model/point_history_center.hdf5
# Epoch 98/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9522 - accuracy: 0.6299 - val_loss: 1.0021 - val_accuracy: 0.5846
#
# Epoch 00098: saving model to lstm_model/point_history_center.hdf5
# Epoch 99/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9377 - accuracy: 0.6176 - val_loss: 0.9903 - val_accuracy: 0.5882
#
# Epoch 00099: saving model to lstm_model/point_history_center.hdf5
# Epoch 100/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9218 - accuracy: 0.6287 - val_loss: 0.9802 - val_accuracy: 0.5882
#
# Epoch 00100: saving model to lstm_model/point_history_center.hdf5
# Epoch 101/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9387 - accuracy: 0.6336 - val_loss: 0.9915 - val_accuracy: 0.5919
#
# Epoch 00101: saving model to lstm_model/point_history_center.hdf5
# Epoch 102/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9392 - accuracy: 0.6385 - val_loss: 0.9729 - val_accuracy: 0.5882
#
# Epoch 00102: saving model to lstm_model/point_history_center.hdf5
# Epoch 103/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9363 - accuracy: 0.6275 - val_loss: 0.9815 - val_accuracy: 0.5846
#
# Epoch 00103: saving model to lstm_model/point_history_center.hdf5
# Epoch 104/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9200 - accuracy: 0.6397 - val_loss: 0.9725 - val_accuracy: 0.5846
#
# Epoch 00104: saving model to lstm_model/point_history_center.hdf5
# Epoch 105/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9160 - accuracy: 0.6409 - val_loss: 0.9739 - val_accuracy: 0.5846
#
# Epoch 00105: saving model to lstm_model/point_history_center.hdf5
# Epoch 106/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9048 - accuracy: 0.6360 - val_loss: 0.9706 - val_accuracy: 0.5846
#
# Epoch 00106: saving model to lstm_model/point_history_center.hdf5
# Epoch 107/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9138 - accuracy: 0.6250 - val_loss: 0.9749 - val_accuracy: 0.5956
#
# Epoch 00107: saving model to lstm_model/point_history_center.hdf5
# Epoch 108/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9085 - accuracy: 0.6446 - val_loss: 0.9519 - val_accuracy: 0.5919
#
# Epoch 00108: saving model to lstm_model/point_history_center.hdf5
# Epoch 109/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.9189 - accuracy: 0.6483 - val_loss: 0.9426 - val_accuracy: 0.5956
#
# Epoch 00109: saving model to lstm_model/point_history_center.hdf5
# Epoch 110/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8917 - accuracy: 0.6556 - val_loss: 0.9403 - val_accuracy: 0.5956
#
# Epoch 00110: saving model to lstm_model/point_history_center.hdf5
# Epoch 111/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8940 - accuracy: 0.6458 - val_loss: 0.9569 - val_accuracy: 0.5993
#
# Epoch 00111: saving model to lstm_model/point_history_center.hdf5
# Epoch 112/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8959 - accuracy: 0.6446 - val_loss: 0.9298 - val_accuracy: 0.5956
#
# Epoch 00112: saving model to lstm_model/point_history_center.hdf5
# Epoch 113/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8867 - accuracy: 0.6446 - val_loss: 0.9416 - val_accuracy: 0.5993
#
# Epoch 00113: saving model to lstm_model/point_history_center.hdf5
# Epoch 114/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8854 - accuracy: 0.6520 - val_loss: 0.9329 - val_accuracy: 0.6029
#
# Epoch 00114: saving model to lstm_model/point_history_center.hdf5
# Epoch 115/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8812 - accuracy: 0.6409 - val_loss: 0.9370 - val_accuracy: 0.5993
#
# Epoch 00115: saving model to lstm_model/point_history_center.hdf5
# Epoch 116/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8705 - accuracy: 0.6544 - val_loss: 0.9243 - val_accuracy: 0.5993
#
# Epoch 00116: saving model to lstm_model/point_history_center.hdf5
# Epoch 117/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8721 - accuracy: 0.6569 - val_loss: 0.9313 - val_accuracy: 0.6066
#
# Epoch 00117: saving model to lstm_model/point_history_center.hdf5
# Epoch 118/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.8697 - accuracy: 0.6471 - val_loss: 0.9078 - val_accuracy: 0.6029
#
# Epoch 00118: saving model to lstm_model/point_history_center.hdf5
# Epoch 119/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8630 - accuracy: 0.6593 - val_loss: 0.9261 - val_accuracy: 0.6066
#
# Epoch 00119: saving model to lstm_model/point_history_center.hdf5
# Epoch 120/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8571 - accuracy: 0.6495 - val_loss: 0.9275 - val_accuracy: 0.6103
#
# Epoch 00120: saving model to lstm_model/point_history_center.hdf5
# Epoch 121/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8629 - accuracy: 0.6532 - val_loss: 0.9113 - val_accuracy: 0.6066
#
# Epoch 00121: saving model to lstm_model/point_history_center.hdf5
# Epoch 122/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8496 - accuracy: 0.6507 - val_loss: 0.9035 - val_accuracy: 0.6066
#
# Epoch 00122: saving model to lstm_model/point_history_center.hdf5
# Epoch 123/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8478 - accuracy: 0.6630 - val_loss: 0.8981 - val_accuracy: 0.6103
#
# Epoch 00123: saving model to lstm_model/point_history_center.hdf5
# Epoch 124/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8567 - accuracy: 0.6642 - val_loss: 0.8940 - val_accuracy: 0.6066
#
# Epoch 00124: saving model to lstm_model/point_history_center.hdf5
# Epoch 125/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8420 - accuracy: 0.6654 - val_loss: 0.8999 - val_accuracy: 0.6029
#
# Epoch 00125: saving model to lstm_model/point_history_center.hdf5
# Epoch 126/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8285 - accuracy: 0.6618 - val_loss: 0.8946 - val_accuracy: 0.6029
#
# Epoch 00126: saving model to lstm_model/point_history_center.hdf5
# Epoch 127/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8369 - accuracy: 0.6520 - val_loss: 0.8924 - val_accuracy: 0.6029
#
# Epoch 00127: saving model to lstm_model/point_history_center.hdf5
# Epoch 128/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8192 - accuracy: 0.6605 - val_loss: 0.8804 - val_accuracy: 0.6029
#
# Epoch 00128: saving model to lstm_model/point_history_center.hdf5
# Epoch 129/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8396 - accuracy: 0.6618 - val_loss: 0.9018 - val_accuracy: 0.6140
#
# Epoch 00129: saving model to lstm_model/point_history_center.hdf5
# Epoch 130/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8114 - accuracy: 0.6716 - val_loss: 0.8824 - val_accuracy: 0.6176
#
# Epoch 00130: saving model to lstm_model/point_history_center.hdf5
# Epoch 131/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8095 - accuracy: 0.6679 - val_loss: 0.8913 - val_accuracy: 0.6176
#
# Epoch 00131: saving model to lstm_model/point_history_center.hdf5
# Epoch 132/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8118 - accuracy: 0.6703 - val_loss: 0.8850 - val_accuracy: 0.6176
#
# Epoch 00132: saving model to lstm_model/point_history_center.hdf5
# Epoch 133/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8067 - accuracy: 0.6740 - val_loss: 0.8663 - val_accuracy: 0.6176
#
# Epoch 00133: saving model to lstm_model/point_history_center.hdf5
# Epoch 134/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7967 - accuracy: 0.6740 - val_loss: 0.8752 - val_accuracy: 0.6213
#
# Epoch 00134: saving model to lstm_model/point_history_center.hdf5
# Epoch 135/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8123 - accuracy: 0.6728 - val_loss: 0.8662 - val_accuracy: 0.6176
#
# Epoch 00135: saving model to lstm_model/point_history_center.hdf5
# Epoch 136/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8059 - accuracy: 0.6814 - val_loss: 0.8660 - val_accuracy: 0.6250
#
# Epoch 00136: saving model to lstm_model/point_history_center.hdf5
# Epoch 137/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8002 - accuracy: 0.6814 - val_loss: 0.8540 - val_accuracy: 0.6213
#
# Epoch 00137: saving model to lstm_model/point_history_center.hdf5
# Epoch 138/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.8038 - accuracy: 0.6814 - val_loss: 0.8488 - val_accuracy: 0.6140
#
# Epoch 00138: saving model to lstm_model/point_history_center.hdf5
# Epoch 139/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7922 - accuracy: 0.6850 - val_loss: 0.8568 - val_accuracy: 0.6213
#
# Epoch 00139: saving model to lstm_model/point_history_center.hdf5
# Epoch 140/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7849 - accuracy: 0.6838 - val_loss: 0.8424 - val_accuracy: 0.6213
#
# Epoch 00140: saving model to lstm_model/point_history_center.hdf5
# Epoch 141/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7972 - accuracy: 0.6740 - val_loss: 0.8711 - val_accuracy: 0.6434
#
# Epoch 00141: saving model to lstm_model/point_history_center.hdf5
# Epoch 142/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7760 - accuracy: 0.6949 - val_loss: 0.8399 - val_accuracy: 0.6397
#
# Epoch 00142: saving model to lstm_model/point_history_center.hdf5
# Epoch 143/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7747 - accuracy: 0.6949 - val_loss: 0.8476 - val_accuracy: 0.6434
#
# Epoch 00143: saving model to lstm_model/point_history_center.hdf5
# Epoch 144/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7833 - accuracy: 0.6936 - val_loss: 0.8321 - val_accuracy: 0.6434
#
# Epoch 00144: saving model to lstm_model/point_history_center.hdf5
# Epoch 145/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7690 - accuracy: 0.6998 - val_loss: 0.8425 - val_accuracy: 0.6507
#
# Epoch 00145: saving model to lstm_model/point_history_center.hdf5
# Epoch 146/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7759 - accuracy: 0.6924 - val_loss: 0.8463 - val_accuracy: 0.6581
#
# Epoch 00146: saving model to lstm_model/point_history_center.hdf5
# Epoch 147/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7530 - accuracy: 0.7047 - val_loss: 0.8206 - val_accuracy: 0.6397
#
# Epoch 00147: saving model to lstm_model/point_history_center.hdf5
# Epoch 148/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7608 - accuracy: 0.6936 - val_loss: 0.8382 - val_accuracy: 0.6471
#
# Epoch 00148: saving model to lstm_model/point_history_center.hdf5
# Epoch 149/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7641 - accuracy: 0.7022 - val_loss: 0.8270 - val_accuracy: 0.6471
#
# Epoch 00149: saving model to lstm_model/point_history_center.hdf5
# Epoch 150/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7666 - accuracy: 0.6924 - val_loss: 0.8222 - val_accuracy: 0.6507
#
# Epoch 00150: saving model to lstm_model/point_history_center.hdf5
# Epoch 151/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7354 - accuracy: 0.7206 - val_loss: 0.8244 - val_accuracy: 0.6544
#
# Epoch 00151: saving model to lstm_model/point_history_center.hdf5
# Epoch 152/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7441 - accuracy: 0.7047 - val_loss: 0.8278 - val_accuracy: 0.6544
#
# Epoch 00152: saving model to lstm_model/point_history_center.hdf5
# Epoch 153/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7423 - accuracy: 0.7157 - val_loss: 0.8264 - val_accuracy: 0.6654
#
# Epoch 00153: saving model to lstm_model/point_history_center.hdf5
# Epoch 154/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7515 - accuracy: 0.6961 - val_loss: 0.8078 - val_accuracy: 0.6544
#
# Epoch 00154: saving model to lstm_model/point_history_center.hdf5
# Epoch 155/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7371 - accuracy: 0.7059 - val_loss: 0.8045 - val_accuracy: 0.6654
#
# Epoch 00155: saving model to lstm_model/point_history_center.hdf5
# Epoch 156/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7400 - accuracy: 0.7071 - val_loss: 0.8089 - val_accuracy: 0.6691
#
# Epoch 00156: saving model to lstm_model/point_history_center.hdf5
# Epoch 157/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7290 - accuracy: 0.7157 - val_loss: 0.7984 - val_accuracy: 0.6654
#
# Epoch 00157: saving model to lstm_model/point_history_center.hdf5
# Epoch 158/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7254 - accuracy: 0.7230 - val_loss: 0.8010 - val_accuracy: 0.6728
#
# Epoch 00158: saving model to lstm_model/point_history_center.hdf5
# Epoch 159/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7120 - accuracy: 0.7304 - val_loss: 0.7997 - val_accuracy: 0.6728
#
# Epoch 00159: saving model to lstm_model/point_history_center.hdf5
# Epoch 160/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7118 - accuracy: 0.7181 - val_loss: 0.7844 - val_accuracy: 0.6728
#
# Epoch 00160: saving model to lstm_model/point_history_center.hdf5
# Epoch 161/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7156 - accuracy: 0.7206 - val_loss: 0.7996 - val_accuracy: 0.6691
#
# Epoch 00161: saving model to lstm_model/point_history_center.hdf5
# Epoch 162/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7046 - accuracy: 0.7255 - val_loss: 0.8026 - val_accuracy: 0.6728
#
# Epoch 00162: saving model to lstm_model/point_history_center.hdf5
# Epoch 163/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7109 - accuracy: 0.7230 - val_loss: 0.7882 - val_accuracy: 0.6765
#
# Epoch 00163: saving model to lstm_model/point_history_center.hdf5
# Epoch 164/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7035 - accuracy: 0.7255 - val_loss: 0.7723 - val_accuracy: 0.6728
#
# Epoch 00164: saving model to lstm_model/point_history_center.hdf5
# Epoch 165/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7247 - accuracy: 0.7194 - val_loss: 0.7765 - val_accuracy: 0.6801
#
# Epoch 00165: saving model to lstm_model/point_history_center.hdf5
# Epoch 166/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6890 - accuracy: 0.7488 - val_loss: 0.7791 - val_accuracy: 0.6765
#
# Epoch 00166: saving model to lstm_model/point_history_center.hdf5
# Epoch 167/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6991 - accuracy: 0.7255 - val_loss: 0.7802 - val_accuracy: 0.6801
#
# Epoch 00167: saving model to lstm_model/point_history_center.hdf5
# Epoch 168/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.7328 - val_loss: 0.7724 - val_accuracy: 0.6838
#
# Epoch 00168: saving model to lstm_model/point_history_center.hdf5
# Epoch 169/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6971 - accuracy: 0.7218 - val_loss: 0.7732 - val_accuracy: 0.6838
#
# Epoch 00169: saving model to lstm_model/point_history_center.hdf5
# Epoch 170/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6959 - accuracy: 0.7414 - val_loss: 0.7708 - val_accuracy: 0.6838
#
# Epoch 00170: saving model to lstm_model/point_history_center.hdf5
# Epoch 171/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7041 - accuracy: 0.7267 - val_loss: 0.7745 - val_accuracy: 0.6875
#
# Epoch 00171: saving model to lstm_model/point_history_center.hdf5
# Epoch 172/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.7341 - val_loss: 0.7630 - val_accuracy: 0.6838
#
# Epoch 00172: saving model to lstm_model/point_history_center.hdf5
# Epoch 173/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6756 - accuracy: 0.7402 - val_loss: 0.7529 - val_accuracy: 0.6875
#
# Epoch 00173: saving model to lstm_model/point_history_center.hdf5
# Epoch 174/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6829 - accuracy: 0.7279 - val_loss: 0.7394 - val_accuracy: 0.6875
#
# Epoch 00174: saving model to lstm_model/point_history_center.hdf5
# Epoch 175/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6684 - accuracy: 0.7353 - val_loss: 0.7599 - val_accuracy: 0.6875
#
# Epoch 00175: saving model to lstm_model/point_history_center.hdf5
# Epoch 176/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6768 - accuracy: 0.7377 - val_loss: 0.7451 - val_accuracy: 0.6912
#
# Epoch 00176: saving model to lstm_model/point_history_center.hdf5
# Epoch 177/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6662 - accuracy: 0.7341 - val_loss: 0.7465 - val_accuracy: 0.6838
#
# Epoch 00177: saving model to lstm_model/point_history_center.hdf5
# Epoch 178/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6577 - accuracy: 0.7390 - val_loss: 0.7445 - val_accuracy: 0.6875
#
# Epoch 00178: saving model to lstm_model/point_history_center.hdf5
# Epoch 179/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6644 - accuracy: 0.7353 - val_loss: 0.7515 - val_accuracy: 0.6912
#
# Epoch 00179: saving model to lstm_model/point_history_center.hdf5
# Epoch 180/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6542 - accuracy: 0.7426 - val_loss: 0.7415 - val_accuracy: 0.6875
#
# Epoch 00180: saving model to lstm_model/point_history_center.hdf5
# Epoch 181/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6640 - accuracy: 0.7365 - val_loss: 0.7313 - val_accuracy: 0.6912
#
# Epoch 00181: saving model to lstm_model/point_history_center.hdf5
# Epoch 182/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.7475 - val_loss: 0.7346 - val_accuracy: 0.6875
#
# Epoch 00182: saving model to lstm_model/point_history_center.hdf5
# Epoch 183/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6729 - accuracy: 0.7341 - val_loss: 0.7318 - val_accuracy: 0.6912
#
# Epoch 00183: saving model to lstm_model/point_history_center.hdf5
# Epoch 184/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6495 - accuracy: 0.7365 - val_loss: 0.7123 - val_accuracy: 0.6912
#
# Epoch 00184: saving model to lstm_model/point_history_center.hdf5
# Epoch 185/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6419 - accuracy: 0.7451 - val_loss: 0.7218 - val_accuracy: 0.6912
#
# Epoch 00185: saving model to lstm_model/point_history_center.hdf5
# Epoch 186/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.7537 - val_loss: 0.7197 - val_accuracy: 0.6912
#
# Epoch 00186: saving model to lstm_model/point_history_center.hdf5
# Epoch 187/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.7365 - val_loss: 0.7218 - val_accuracy: 0.6949
#
# Epoch 00187: saving model to lstm_model/point_history_center.hdf5
# Epoch 188/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6323 - accuracy: 0.7537 - val_loss: 0.7040 - val_accuracy: 0.6985
#
# Epoch 00188: saving model to lstm_model/point_history_center.hdf5
# Epoch 189/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.7316 - val_loss: 0.7198 - val_accuracy: 0.6949
#
# Epoch 00189: saving model to lstm_model/point_history_center.hdf5
# Epoch 190/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6304 - accuracy: 0.7439 - val_loss: 0.7035 - val_accuracy: 0.6949
#
# Epoch 00190: saving model to lstm_model/point_history_center.hdf5
# Epoch 191/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6258 - accuracy: 0.7402 - val_loss: 0.7117 - val_accuracy: 0.6985
#
# Epoch 00191: saving model to lstm_model/point_history_center.hdf5
# Epoch 192/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.7488 - val_loss: 0.6981 - val_accuracy: 0.7022
#
# Epoch 00192: saving model to lstm_model/point_history_center.hdf5
# Epoch 193/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.7475 - val_loss: 0.6981 - val_accuracy: 0.6949
#
# Epoch 00193: saving model to lstm_model/point_history_center.hdf5
# Epoch 194/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6115 - accuracy: 0.7574 - val_loss: 0.7074 - val_accuracy: 0.7022
#
# Epoch 00194: saving model to lstm_model/point_history_center.hdf5
# Epoch 195/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6188 - accuracy: 0.7439 - val_loss: 0.6965 - val_accuracy: 0.6949
#
# Epoch 00195: saving model to lstm_model/point_history_center.hdf5
# Epoch 196/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6021 - accuracy: 0.7512 - val_loss: 0.6764 - val_accuracy: 0.6875
#
# Epoch 00196: saving model to lstm_model/point_history_center.hdf5
# Epoch 197/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6061 - accuracy: 0.7512 - val_loss: 0.7007 - val_accuracy: 0.6949
#
# Epoch 00197: saving model to lstm_model/point_history_center.hdf5
# Epoch 198/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6213 - accuracy: 0.7365 - val_loss: 0.7005 - val_accuracy: 0.6985
#
# Epoch 00198: saving model to lstm_model/point_history_center.hdf5
# Epoch 199/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6149 - accuracy: 0.7402 - val_loss: 0.6848 - val_accuracy: 0.6912
#
# Epoch 00199: saving model to lstm_model/point_history_center.hdf5
# Epoch 200/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.7525 - val_loss: 0.6971 - val_accuracy: 0.7022
#
# Epoch 00200: saving model to lstm_model/point_history_center.hdf5
# Epoch 201/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6025 - accuracy: 0.7512 - val_loss: 0.6810 - val_accuracy: 0.6949
#
# Epoch 00201: saving model to lstm_model/point_history_center.hdf5
# Epoch 202/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6037 - accuracy: 0.7647 - val_loss: 0.6651 - val_accuracy: 0.6985
#
# Epoch 00202: saving model to lstm_model/point_history_center.hdf5
# Epoch 203/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6119 - accuracy: 0.7525 - val_loss: 0.6735 - val_accuracy: 0.7022
#
# Epoch 00203: saving model to lstm_model/point_history_center.hdf5
# Epoch 204/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6025 - accuracy: 0.7500 - val_loss: 0.6696 - val_accuracy: 0.7022
#
# Epoch 00204: saving model to lstm_model/point_history_center.hdf5
# Epoch 205/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.7623 - val_loss: 0.6719 - val_accuracy: 0.7059
#
# Epoch 00205: saving model to lstm_model/point_history_center.hdf5
# Epoch 206/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5905 - accuracy: 0.7721 - val_loss: 0.6705 - val_accuracy: 0.7096
#
# Epoch 00206: saving model to lstm_model/point_history_center.hdf5
# Epoch 207/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5952 - accuracy: 0.7512 - val_loss: 0.6663 - val_accuracy: 0.7169
#
# Epoch 00207: saving model to lstm_model/point_history_center.hdf5
# Epoch 208/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5995 - accuracy: 0.7659 - val_loss: 0.6720 - val_accuracy: 0.7169
#
# Epoch 00208: saving model to lstm_model/point_history_center.hdf5
# Epoch 209/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.7635 - val_loss: 0.6651 - val_accuracy: 0.7243
#
# Epoch 00209: saving model to lstm_model/point_history_center.hdf5
# Epoch 210/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5846 - accuracy: 0.7647 - val_loss: 0.6413 - val_accuracy: 0.7390
#
# Epoch 00210: saving model to lstm_model/point_history_center.hdf5
# Epoch 211/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5882 - accuracy: 0.7635 - val_loss: 0.6704 - val_accuracy: 0.7574
#
# Epoch 00211: saving model to lstm_model/point_history_center.hdf5
# Epoch 212/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5863 - accuracy: 0.7721 - val_loss: 0.6437 - val_accuracy: 0.7390
#
# Epoch 00212: saving model to lstm_model/point_history_center.hdf5
# Epoch 213/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5778 - accuracy: 0.7770 - val_loss: 0.6615 - val_accuracy: 0.7574
#
# Epoch 00213: saving model to lstm_model/point_history_center.hdf5
# Epoch 214/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7684 - val_loss: 0.6480 - val_accuracy: 0.7574
#
# Epoch 00214: saving model to lstm_model/point_history_center.hdf5
# Epoch 215/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5789 - accuracy: 0.7684 - val_loss: 0.6581 - val_accuracy: 0.7684
#
# Epoch 00215: saving model to lstm_model/point_history_center.hdf5
# Epoch 216/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5673 - accuracy: 0.7831 - val_loss: 0.6432 - val_accuracy: 0.7537
#
# Epoch 00216: saving model to lstm_model/point_history_center.hdf5
# Epoch 217/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.5815 - accuracy: 0.7745 - val_loss: 0.6395 - val_accuracy: 0.7500
#
# Epoch 00217: saving model to lstm_model/point_history_center.hdf5
# Epoch 218/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5665 - accuracy: 0.7819 - val_loss: 0.6435 - val_accuracy: 0.7647
#
# Epoch 00218: saving model to lstm_model/point_history_center.hdf5
# Epoch 219/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5575 - accuracy: 0.7917 - val_loss: 0.6475 - val_accuracy: 0.7684
#
# Epoch 00219: saving model to lstm_model/point_history_center.hdf5
# Epoch 220/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5593 - accuracy: 0.7770 - val_loss: 0.6336 - val_accuracy: 0.7574
#
# Epoch 00220: saving model to lstm_model/point_history_center.hdf5
# Epoch 221/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5610 - accuracy: 0.7757 - val_loss: 0.6462 - val_accuracy: 0.7610
#
# Epoch 00221: saving model to lstm_model/point_history_center.hdf5
# Epoch 222/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5688 - accuracy: 0.7721 - val_loss: 0.6215 - val_accuracy: 0.7610
#
# Epoch 00222: saving model to lstm_model/point_history_center.hdf5
# Epoch 223/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.5673 - accuracy: 0.7819 - val_loss: 0.6234 - val_accuracy: 0.7721
#
# Epoch 00223: saving model to lstm_model/point_history_center.hdf5
# Epoch 224/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.7966 - val_loss: 0.6209 - val_accuracy: 0.7684
#
# Epoch 00224: saving model to lstm_model/point_history_center.hdf5
# Epoch 225/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.5652 - accuracy: 0.7953 - val_loss: 0.6397 - val_accuracy: 0.7757
#
# Epoch 00225: saving model to lstm_model/point_history_center.hdf5
# Epoch 226/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5653 - accuracy: 0.7843 - val_loss: 0.6236 - val_accuracy: 0.7757
#
# Epoch 00226: saving model to lstm_model/point_history_center.hdf5
# Epoch 227/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5514 - accuracy: 0.7990 - val_loss: 0.6213 - val_accuracy: 0.7684
#
# Epoch 00227: saving model to lstm_model/point_history_center.hdf5
# Epoch 228/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5386 - accuracy: 0.7978 - val_loss: 0.6140 - val_accuracy: 0.7647
#
# ...
#
# Epoch 00636: saving model to lstm_model/point_history_center.hdf5
# Epoch 637/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1505 - accuracy: 0.9596 - val_loss: 0.1598 - val_accuracy: 0.9706
#
# Epoch 00637: saving model to lstm_model/point_history_center.hdf5
# Epoch 638/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.9596 - val_loss: 0.1535 - val_accuracy: 0.9743
#
# Epoch 00638: saving model to lstm_model/point_history_center.hdf5
# Epoch 639/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9485 - val_loss: 0.1509 - val_accuracy: 0.9706
#
# Epoch 00639: saving model to lstm_model/point_history_center.hdf5
# Epoch 640/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.9645 - val_loss: 0.1500 - val_accuracy: 0.9743
#
# Epoch 00640: saving model to lstm_model/point_history_center.hdf5
# Epoch 641/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9657 - val_loss: 0.1543 - val_accuracy: 0.9706
#
# Epoch 00641: saving model to lstm_model/point_history_center.hdf5
# Epoch 642/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9694 - val_loss: 0.1581 - val_accuracy: 0.9669
#
# Epoch 00642: saving model to lstm_model/point_history_center.hdf5
# Epoch 643/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9620 - val_loss: 0.1519 - val_accuracy: 0.9779
#
# Epoch 00643: saving model to lstm_model/point_history_center.hdf5
# Epoch 644/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1526 - accuracy: 0.9559 - val_loss: 0.1520 - val_accuracy: 0.9706
#
# Epoch 00644: saving model to lstm_model/point_history_center.hdf5
# Epoch 645/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1449 - accuracy: 0.9534 - val_loss: 0.1481 - val_accuracy: 0.9706
#
# Epoch 00645: saving model to lstm_model/point_history_center.hdf5
# Epoch 646/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1388 - accuracy: 0.9608 - val_loss: 0.1535 - val_accuracy: 0.9706
#
# Epoch 00646: saving model to lstm_model/point_history_center.hdf5
# Epoch 647/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1425 - accuracy: 0.9547 - val_loss: 0.1474 - val_accuracy: 0.9706
#
# Epoch 00647: saving model to lstm_model/point_history_center.hdf5
# Epoch 648/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1476 - accuracy: 0.9596 - val_loss: 0.1470 - val_accuracy: 0.9706
#
# Epoch 00648: saving model to lstm_model/point_history_center.hdf5
# Epoch 649/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.9632 - val_loss: 0.1518 - val_accuracy: 0.9669
#
# Epoch 00649: saving model to lstm_model/point_history_center.hdf5
# Epoch 650/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1306 - accuracy: 0.9571 - val_loss: 0.1514 - val_accuracy: 0.9706
#
# Epoch 00650: saving model to lstm_model/point_history_center.hdf5
# Epoch 651/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9657 - val_loss: 0.1530 - val_accuracy: 0.9669
#
# Epoch 00651: saving model to lstm_model/point_history_center.hdf5
# Epoch 652/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1358 - accuracy: 0.9620 - val_loss: 0.1495 - val_accuracy: 0.9706
#
# Epoch 00652: saving model to lstm_model/point_history_center.hdf5
# Epoch 653/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1266 - accuracy: 0.9608 - val_loss: 0.1564 - val_accuracy: 0.9706
#
# Epoch 00653: saving model to lstm_model/point_history_center.hdf5
# Epoch 654/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9608 - val_loss: 0.1453 - val_accuracy: 0.9706
#
# Epoch 00654: saving model to lstm_model/point_history_center.hdf5
# Epoch 655/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9583 - val_loss: 0.1427 - val_accuracy: 0.9706
#
# Epoch 00655: saving model to lstm_model/point_history_center.hdf5
# Epoch 656/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9669 - val_loss: 0.1449 - val_accuracy: 0.9706
#
# Epoch 00656: saving model to lstm_model/point_history_center.hdf5
# Epoch 657/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1533 - accuracy: 0.9485 - val_loss: 0.1508 - val_accuracy: 0.9706
#
# Epoch 00657: saving model to lstm_model/point_history_center.hdf5
# Epoch 658/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1283 - accuracy: 0.9669 - val_loss: 0.1471 - val_accuracy: 0.9706
#
# Epoch 00658: saving model to lstm_model/point_history_center.hdf5
# Epoch 659/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9547 - val_loss: 0.1537 - val_accuracy: 0.9706
#
# Epoch 00659: saving model to lstm_model/point_history_center.hdf5
# Epoch 660/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9596 - val_loss: 0.1430 - val_accuracy: 0.9669
#
# Epoch 00660: saving model to lstm_model/point_history_center.hdf5
# Epoch 661/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9620 - val_loss: 0.1472 - val_accuracy: 0.9706
#
# Epoch 00661: saving model to lstm_model/point_history_center.hdf5
# Epoch 662/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1364 - accuracy: 0.9632 - val_loss: 0.1460 - val_accuracy: 0.9706
#
# Epoch 00662: saving model to lstm_model/point_history_center.hdf5
# Epoch 663/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1310 - accuracy: 0.9657 - val_loss: 0.1430 - val_accuracy: 0.9706
#
# Epoch 00663: saving model to lstm_model/point_history_center.hdf5
# Epoch 664/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9694 - val_loss: 0.1477 - val_accuracy: 0.9706
#
# Epoch 00664: saving model to lstm_model/point_history_center.hdf5
# Epoch 665/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9718 - val_loss: 0.1446 - val_accuracy: 0.9706
#
# Epoch 00665: saving model to lstm_model/point_history_center.hdf5
# Epoch 666/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1181 - accuracy: 0.9669 - val_loss: 0.1437 - val_accuracy: 0.9706
#
# Epoch 00666: saving model to lstm_model/point_history_center.hdf5
# Epoch 667/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1371 - accuracy: 0.9596 - val_loss: 0.1452 - val_accuracy: 0.9669
#
# Epoch 00667: saving model to lstm_model/point_history_center.hdf5
# Epoch 668/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.9559 - val_loss: 0.1467 - val_accuracy: 0.9669
#
# Epoch 00668: saving model to lstm_model/point_history_center.hdf5
# Epoch 669/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1274 - accuracy: 0.9571 - val_loss: 0.1423 - val_accuracy: 0.9669
#
# Epoch 00669: saving model to lstm_model/point_history_center.hdf5
# Epoch 670/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1399 - accuracy: 0.9596 - val_loss: 0.1449 - val_accuracy: 0.9706
#
# Epoch 00670: saving model to lstm_model/point_history_center.hdf5
# Epoch 671/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9669 - val_loss: 0.1466 - val_accuracy: 0.9706
#
# Epoch 00671: saving model to lstm_model/point_history_center.hdf5
# Epoch 672/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 0.9657 - val_loss: 0.1420 - val_accuracy: 0.9706
#
# Epoch 00672: saving model to lstm_model/point_history_center.hdf5
# Epoch 673/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1550 - accuracy: 0.9498 - val_loss: 0.1433 - val_accuracy: 0.9706
#
# Epoch 00673: saving model to lstm_model/point_history_center.hdf5
# Epoch 674/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9645 - val_loss: 0.1443 - val_accuracy: 0.9706
#
# Epoch 00674: saving model to lstm_model/point_history_center.hdf5
# Epoch 675/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9620 - val_loss: 0.1400 - val_accuracy: 0.9669
#
# Epoch 00675: saving model to lstm_model/point_history_center.hdf5
# Epoch 676/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9547 - val_loss: 0.1408 - val_accuracy: 0.9706
#
# Epoch 00676: saving model to lstm_model/point_history_center.hdf5
# Epoch 677/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1392 - accuracy: 0.9498 - val_loss: 0.1451 - val_accuracy: 0.9706
#
# Epoch 00677: saving model to lstm_model/point_history_center.hdf5
# Epoch 678/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.9669 - val_loss: 0.1407 - val_accuracy: 0.9706
#
# Epoch 00678: saving model to lstm_model/point_history_center.hdf5
# Epoch 679/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1208 - accuracy: 0.9718 - val_loss: 0.1351 - val_accuracy: 0.9706
#
# Epoch 00679: saving model to lstm_model/point_history_center.hdf5
# Epoch 680/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9547 - val_loss: 0.1464 - val_accuracy: 0.9706
#
# Epoch 00680: saving model to lstm_model/point_history_center.hdf5
# Epoch 681/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1288 - accuracy: 0.9669 - val_loss: 0.1375 - val_accuracy: 0.9706
#
# Epoch 00681: saving model to lstm_model/point_history_center.hdf5
# Epoch 682/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9632 - val_loss: 0.1364 - val_accuracy: 0.9706
#
# Epoch 00682: saving model to lstm_model/point_history_center.hdf5
# Epoch 683/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1147 - accuracy: 0.9669 - val_loss: 0.1331 - val_accuracy: 0.9779
#
# Epoch 00683: saving model to lstm_model/point_history_center.hdf5
# Epoch 684/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1239 - accuracy: 0.9583 - val_loss: 0.1381 - val_accuracy: 0.9743
#
# Epoch 00684: saving model to lstm_model/point_history_center.hdf5
# Epoch 685/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1253 - accuracy: 0.9657 - val_loss: 0.1466 - val_accuracy: 0.9743
#
# Epoch 00685: saving model to lstm_model/point_history_center.hdf5
# Epoch 686/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1083 - accuracy: 0.9718 - val_loss: 0.1408 - val_accuracy: 0.9706
#
# Epoch 00686: saving model to lstm_model/point_history_center.hdf5
# Epoch 687/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.9694 - val_loss: 0.1422 - val_accuracy: 0.9706
#
# Epoch 00687: saving model to lstm_model/point_history_center.hdf5
# Epoch 688/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9657 - val_loss: 0.1362 - val_accuracy: 0.9779
#
# Epoch 00688: saving model to lstm_model/point_history_center.hdf5
# Epoch 689/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1269 - accuracy: 0.9657 - val_loss: 0.1362 - val_accuracy: 0.9706
#
# Epoch 00689: saving model to lstm_model/point_history_center.hdf5
# Epoch 690/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.9547 - val_loss: 0.1369 - val_accuracy: 0.9743
#
# Epoch 00690: saving model to lstm_model/point_history_center.hdf5
# Epoch 691/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1163 - accuracy: 0.9706 - val_loss: 0.1312 - val_accuracy: 0.9706
#
# Epoch 00691: saving model to lstm_model/point_history_center.hdf5
# Epoch 692/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.9645 - val_loss: 0.1366 - val_accuracy: 0.9706
#
# Epoch 00692: saving model to lstm_model/point_history_center.hdf5
# Epoch 693/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9645 - val_loss: 0.1397 - val_accuracy: 0.9706
#
# Epoch 00693: saving model to lstm_model/point_history_center.hdf5
# Epoch 694/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9755 - val_loss: 0.1382 - val_accuracy: 0.9706
#
# Epoch 00694: saving model to lstm_model/point_history_center.hdf5
# Epoch 695/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1160 - accuracy: 0.9669 - val_loss: 0.1413 - val_accuracy: 0.9706
#
# Epoch 00695: saving model to lstm_model/point_history_center.hdf5
# Epoch 696/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1195 - accuracy: 0.9694 - val_loss: 0.1400 - val_accuracy: 0.9779
#
# Epoch 00696: saving model to lstm_model/point_history_center.hdf5
# Epoch 697/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1199 - accuracy: 0.9645 - val_loss: 0.1523 - val_accuracy: 0.9779
#
# Epoch 00697: saving model to lstm_model/point_history_center.hdf5
# Epoch 698/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9669 - val_loss: 0.1446 - val_accuracy: 0.9779
#
# Epoch 00698: saving model to lstm_model/point_history_center.hdf5
# Epoch 699/2000
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9657 - val_loss: 0.1367 - val_accuracy: 0.9706
#
# Epoch 00699: saving model to lstm_model/point_history_center.hdf5
# Epoch 700/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1150 - accuracy: 0.9681 - val_loss: 0.1339 - val_accuracy: 0.9743
#
# Epoch 00700: saving model to lstm_model/point_history_center.hdf5
# Epoch 701/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9632 - val_loss: 0.1421 - val_accuracy: 0.9706
#
# Epoch 00701: saving model to lstm_model/point_history_center.hdf5
# Epoch 702/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1187 - accuracy: 0.9681 - val_loss: 0.1355 - val_accuracy: 0.9706
#
# Epoch 00702: saving model to lstm_model/point_history_center.hdf5
# Epoch 703/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9657 - val_loss: 0.1354 - val_accuracy: 0.9743
#
# Epoch 00703: saving model to lstm_model/point_history_center.hdf5
# Epoch 704/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9755 - val_loss: 0.1339 - val_accuracy: 0.9743
#
# Epoch 00704: saving model to lstm_model/point_history_center.hdf5
# Epoch 705/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9669 - val_loss: 0.1361 - val_accuracy: 0.9779
#
# Epoch 00705: saving model to lstm_model/point_history_center.hdf5
# Epoch 706/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9620 - val_loss: 0.1361 - val_accuracy: 0.9779
#
# Epoch 00706: saving model to lstm_model/point_history_center.hdf5
# Epoch 707/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.9583 - val_loss: 0.1412 - val_accuracy: 0.9779
#
# Epoch 00707: saving model to lstm_model/point_history_center.hdf5
# Epoch 708/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9596 - val_loss: 0.1360 - val_accuracy: 0.9779
#
# Epoch 00708: saving model to lstm_model/point_history_center.hdf5
# Epoch 709/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9620 - val_loss: 0.1351 - val_accuracy: 0.9779
#
# Epoch 00709: saving model to lstm_model/point_history_center.hdf5
# Epoch 710/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9583 - val_loss: 0.1325 - val_accuracy: 0.9779
#
# Epoch 00710: saving model to lstm_model/point_history_center.hdf5
# Epoch 711/2000
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9669 - val_loss: 0.1337 - val_accuracy: 0.9779
#
# Epoch 00711: saving model to lstm_model/point_history_center.hdf5
# Epoch 00711: early stopping

# %%
model = tf.keras.models.load_model(model_save_path)

# %%
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# [9.9245113e-01 1.0815546e-05 6.3107138e-05 3.6952709e-04 4.5494607e-04
#  4.1778469e-05 6.6086850e-03]
# 0

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       107
#            1       1.00      1.00      1.00        40
#            2       0.98      1.00      0.99        57
#            3       1.00      0.90      0.95        20
#            4       0.93      1.00      0.97        14
#            5       0.93      0.88      0.90        16
#            6       1.00      0.89      0.94        18
#
#     accuracy                           0.98       272
#    macro avg       0.97      0.95      0.96       272
# weighted avg       0.98      0.98      0.98       272

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('lstm_model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmp4oqu83w1/assets
# INFO:tensorflow:Assets written to: /tmp/tmp4oqu83w1/assets
